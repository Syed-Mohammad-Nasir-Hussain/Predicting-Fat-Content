# %%
# Importing Required Libraries
import pandas as pd
import numpy as np

# %%
x=pd.read_csv('E:\\Data Science - Yogesh\\Linear Regression\\fat.csv') # Reading Input File

# %%
x # Shows Data set
# Out:
#       Waist     FAT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# 5     71.85   21.68
# 6     80.90   29.08
# 7     83.40   32.98
# 8     63.50   11.44
# 9     73.20   32.22
# 10    71.90   28.32
# 11    75.00   43.86
# 12    73.10   38.21
# 13    79.00   42.48
# 14    77.00   30.96
# 15    68.85   55.78
# 16    75.95   43.78
# 17    74.15   33.41
# 18    73.80   43.35
# 19    75.90   29.31
# 20    76.85   36.60
# 21    80.90   40.25
# 22    79.90   35.43
# 23    89.20   60.09
# 24    82.00   45.84
# 25    92.00   70.40
# 26    86.60   83.45
# 27    80.50   84.30
# 28    86.00   78.89
# 29    82.50   64.75
# ..      ...     ...
# 79   109.00  192.00
# 80   103.50  132.00
# 81   110.00  126.00
# 82   110.00  153.00
# 83   112.00  158.00
# 84   108.50  183.00
# 85   104.00  184.00
# 86   111.00  121.00
# 87   108.50  159.00
# 88   121.00  245.00
# 89   109.00  137.00
# 90    97.50  165.00
# 91   105.50  152.00
# ...

# %%
type(x) # shows type of data set
# Out:
# pandas.core.frame.DataFrame

# %%
x.shape # shows number of rows and columns in data set
# Out:
# (109, 2)

# %%
x.head() # shows first 5 records in data set
# Out:
#    Waist    FAT
# 0  74.75  25.72
# 1  72.60  25.89
# 2  81.80  42.60
# 3  83.95  42.80
# 4  74.65  29.84

# %%
x.tail() # shows last 5 records in data set
# Out:
#      Waist    FAT
# 104  100.1  124.0
# 105   93.3   62.2
# 106  101.8  133.0
# 107  107.9  208.0
# 108  108.5  208.0

# %%
x.columns # shows Column Names
# Out:
# Index(['Waist', 'FAT'], dtype='object')

# %%
x.isnull().sum() # Checks for Null values
# Out:
# Waist    0
# FAT      0
# dtype: int64

# %%
x.corr() # Gives Correlation info
# Out:
#           Waist       FAT
# Waist  1.000000  0.818558
# FAT    0.818558  1.000000

# %%
import seaborn as sns # Importing Required Libraries

# %%
sns.pairplot(x.iloc[:,:]) # Shows Pair Plot

# %%
import statsmodels.formula.api as smf # Importing Required Libraries

# %%
m1=smf.ols('FAT~Waist',data=x).fit() # Building Simple Linear Regression model on X data set

# %%
m1.params # Gives Parameters info
# Out:
# Intercept   -215.981488
# Waist          3.458859
# dtype: float64

# %%
m1.summary() # Checking accuracy and significance
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    FAT   R-squared:                       0.670
# Model:                            OLS   Adj. R-squared:                  0.667
# Method:                 Least Squares   F-statistic:                     217.3
# Date:                Mon, 18 Nov 2019   Prob (F-statistic):           1.62e-27
# Time:                        11:31:19   Log-Likelihood:                -534.99
# No. Observations:                 109   AIC:                             1074.
# Df Residuals:                     107   BIC:                             1079.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -215.9815     21.796     -9.909      0.000    -259.190    -172.773
# ...

# %%
pred=m1.predict(x) # Predicting the output

# %%
pred # Shows Predicted Data
# Out:
# 0       42.568252
# 1       35.131704
# 2       66.953210
# 3       74.389758
# 4       42.222366
# 5       32.537559
# 6       63.840237
# 7       72.487385
# 8        3.656083
# 9       37.207020
# 10      32.710502
# 11      43.432966
# 12      36.861134
# 13      57.268404
# 14      50.350685
# 15      22.160981
# 16      46.718883
# 17      40.492936
# 18      39.282335
# 19      46.545940
# 20      49.831856
# 21      63.840237
# 22      60.381377
# 23      92.548770
# 24      67.644982
# 25     102.233576
# 26      83.555735
# 27      62.456693
# 28      81.480420
# 29      69.374412
#           ...
# 79     161.034186
# 80     142.010459
# 81     164.493045
# 82     164.493045
# 83     171.410764
# 84     159.304756
# 85     143.739889
# 86     167.951905
# 87     159.304756
# 88     202.540498
# 89     161.034186
# 90     121.257303
# 91     148.928178
# 92     122.986732
# 93     110.880725
# 94     119.527873
# 95     147.198748
# 96     150.657608
# 97     126.445592
# ...

# %%
x['Predicted Value']=pred # Adding new column to X data set with predicted output data valued

# %%
x # showing the Data set
# Out:
#       Waist     FAT  Predicted Value
# 0     74.75   25.72        42.568252
# 1     72.60   25.89        35.131704
# 2     81.80   42.60        66.953210
# 3     83.95   42.80        74.389758
# 4     74.65   29.84        42.222366
# 5     71.85   21.68        32.537559
# 6     80.90   29.08        63.840237
# 7     83.40   32.98        72.487385
# 8     63.50   11.44         3.656083
# 9     73.20   32.22        37.207020
# 10    71.90   28.32        32.710502
# 11    75.00   43.86        43.432966
# 12    73.10   38.21        36.861134
# 13    79.00   42.48        57.268404
# 14    77.00   30.96        50.350685
# 15    68.85   55.78        22.160981
# 16    75.95   43.78        46.718883
# 17    74.15   33.41        40.492936
# 18    73.80   43.35        39.282335
# 19    75.90   29.31        46.545940
# 20    76.85   36.60        49.831856
# 21    80.90   40.25        63.840237
# 22    79.90   35.43        60.381377
# 23    89.20   60.09        92.548770
# ...
